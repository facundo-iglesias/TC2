# %% [markdown]
# <div class="alert alert-info text-left">
#
# <img src="./rsc/logo_UTN.svg" align="right" width="150" />
#
# <center> <h1>Tarea semanal 2: Filtro Pasa-bajos </h1></center>
#
# <h3> Teoría de circuitos 2 </h3>
# <h3> 2023 </h3>
# <h3> Facundo N. Iglesias </h3>
#
#
# </div>

# %% [markdown]
# <img src="./rsc/circuito.png"  />
# <img src="./rsc/consignas.png"  />

# %%
#LIbrerias utilizadas
from IPython.display import IFrame, display, Math
import sympy as sp
from sympy.abc import s
from sympy.parsing.sympy_parser import parse_expr
from numpy import sqrt
import numpy as np
import matplotlib.pyplot as plt
from pytc2.general import Chebyshev_polynomials 
from pytc2.sistemas_lineales import analyze_sys,  tf2sos_analog
import scipy.signal as sig

# %% [markdown]
# <div class="alert alert-info text-left">
# <center> <h1>Revisión 1.0 </h1></center>
# </div>

# %% [markdown]
# ### Análisis de la función transferencia normalizada
#
# A partir de las ecuaciones circuitales se obtuvo la función transferencia que describe el comportamiento del circuito:
#
# \begin{equation}
# T(s) = - \frac{R_3}{R_1} \frac{\frac{1}{R_3²C²}}{s^2 + s \frac{1}{R_2C} + \frac{1}{R_3²C²}}
# \end{equation}
#
# Como se puede observar la forma de la transferencia es la de un filtro pasa-bajos y sus parámetros carácteristicos son los siguientes:
#
# Frecuencia de corte:
# \begin{equation}
# \omega_0 = \frac{1}{R_3C}
# \end{equation}
#
# Ganancia en la banda de paso:
# \begin{equation}
# K=\frac{R_3}{R_1}
# \end{equation}
#
# Factor de selectividad:
# \begin{equation}
# Q=\frac{R_2}{R_3}
# \end{equation}
#
# Normalizando la transferencia utilizando como norma la frecuencia de corte:
#
# \begin{equation}
# T(s) = - \frac{R_3}{R_1} \frac{1}{s^2 + \frac{R_3}{R_2}s + 1}
# \end{equation}
#
# Como se puede observar en la transferencia tenemos 2 grados de libertad uno para K y otro para Q, luego el desplazamiento en frecuencia se realiza por a partir del valor del capacitor "C". Como el resistor R3 está presente en ambos parámetros, un componente quedará sujeto al valor que se adopte. Por lo tanto, el algoritmo de tunning planteado para ajustar el filtro a los valores solicitados es el siguiente:
#
# 1) Adoptar R3 para cumplir con el factor de calidad del filtro, por lo tanto R2 quedará fijado por dicho valor adoptado.
# 2) Teniendo R3 ajustar R1 para cumplir con la ganancia solicitada en la banda de paso.
# 3) Finalmente, desnormalizar el circuito para trasladar en frecuencia.
#
# Aplicando el algoritmo planteado:
# Para que cumpla con el diseño del filtro el factor de calidad debe ser igual a 3
# \begin{equation}
# R_2 = 3R_3 \rightarrow R_3=1 \rightarrow R_2= 3
# \end{equation}
# Para que la ganancia sea de 20dB, K tiene que ser igual a 10:
# \begin{equation}
# K = \frac{R_3}{R_1} = 10 \rightarrow R_1 = 0,1
# \end{equation}
#
# La función transferencia normalizada en frecuencia que cumple con los parámetros de diseño es:
# \begin{equation}
# \boxed{T(s) = - 10 \frac{1}{s^2 + \frac{1}{3}s + 1}}
# \end{equation}
#
# Se procede a analizar la función transferencia con la libreria analyse_sys de la catedra:

# %%
analyze_sys([sig.TransferFunction([-10], [1,1/3,1])], ['lp_norm'])

# %% [markdown]
# A partir de los gráficos podemos corroboar que:
# #### Gráfico de modulo y fase:
# - Ganancia de 20dB en la banda de paso
# - Como la transferencia está normalizada la frecuencia de corte se encuentra en 1 rad/s.
# - El sobrepico que se da en el frecuencia de corte es de 10dB
#
# \begin{equation}
# Q = 10^{\frac{10dB}{20}} = 3,1622
# \end{equation}
#
# #### Diagrama de polos y ceros:
# - La circunferencia sobre la que se posicionan los polos es de radio unitario producto de la normalización
# - La transferencia tiene dos ceros implicitos en +- infinito.
# - Si analizamos la fase podemos ver que para la continua el aporte de las dos singularidades se cancela iniciando con fase nula o de 180°. Cuando la frecuencia tiende a infinito ambos polos aportan -90° a la transferencia logrando una rotación total de -180°.
#
# #### Diagrama de retardo de grupo:
# - Al igual que en la TS1 los lugares geométricos coinciden pero debemos quedarnos con la forma de la fase que tiene pendiente negativa para que el retardo de grupo sea positivo.

# %% [markdown]
# ### Análisis de la función transferencia de Buttherworth

# %% [markdown]
# En primer lugar vamos a obtener los coeficientes del polinomio de Butterworth por tabla, pero más adelante se calcularan a partir del diagrama de polos y ceros.
#
# <img src="./rsc/tbButter.png"  />

# %% [markdown]
# De la tabla se obtiene:
# Función transferencia:
# \begin{equation}
# T(s) = -10 \frac{1}{s²+\sqrt{2}+1}
# \end{equation}
#
# Factor de calidad:
# \begin{equation}
# Q = \frac{\sqrt{2}}{2}
# \end{equation}
#
# Ubicación de los polos:
# \begin{equation}
# p = -\frac{\sqrt{2}}{2}+-\frac{\sqrt{2}}{2}
# \end{equation}
#
# Se procede a análizar la transferencia de Butterworth para identificar diferencias con la transferencia sin máxima planicidad:

# %%
analyze_sys([sig.TransferFunction([-10], [1,np.sqrt(2),1])], ['lp_butter'])

# %% [markdown]
# #### Gráfico de modulo y fase:
# - En el diagrama de módulo podemos observar ahora la máxima planicidad en la banda de paso.
# - Se destaca también la caída de 40 dB por decada debido al aporte de ambos polos.
# - La fase presenta una respuesta más suavizada.
#
# #### Diagrama de polos y ceros:
# - Una observación importante para hacer es que a medida que las singularidades se alejan del eje "jw" el factor de caldiad Q disminuye.
# - Sabiendo que las singularidades se encuentran equiespaciadas se puede calcular el factor de calidad a partir del ángulo de separación de la siguiente forma:
# \begin{equation}
# Q = \frac{1}{2cos( \varphi)} = \frac{1}{2cos(45°)} = \frac{\sqrt{2}}{2}
# \end{equation}
#
# #### Diagrama de retardo de grupo:
# - Debido a la "suavización" de la fase, el retardo de grupo también responde de una forma más suave.

# %% [markdown]
# ### Simulación del circuito

# %% [markdown]
# Aprovechando que en este trabajo práctico se calcularon las sensibilidades, resulta interesante realizar un análisis de Montecarlo para observar como varía la respuesta del circuito en relación a los valores de los componentes.

# %% [markdown]
# En primer lugar analizamos la transferencia si varía de forma aleatorea el valor de R3 con una tolerancia del 5%, es decir que la simulación tomará 100 valores aleatoreos y equiprobables de una distribución rectangular.
# <img src="./rsc/sim/montecarlo/sim1.png"  />
# Se observa que la función transferencia no varía notablemente debido a que R3 está presente en los 3 parámetros caracteristicos del filtro (f0, Q y K). Se considera
#
# A continuación se repite la simulación pero en este caso variando R2:
# <img src="./rsc/sim/montecarlo/sim2.png"  />
# En este caso se puede ver que la afectación es directamente sobre el Q, cada curva evidencia un sobre impulso diferente
#
# Al aplicar la simulación sobre R1 se obtiene la siguiente familia de curvas:
# <img src="./rsc/sim/montecarlo/sim3.png"  />
# Donde se observa la dependencia de la ganancia en la banda de paso (K) con el resistor R1.
#
# Finalmente variamos el valor de C:
# <img src="./rsc/sim/montecarlo/sim4.png"  />
# Y observamos un leve corrimiento en frecuencia de la respuesta.

# %% [markdown]
# <div class="alert alert-info text-left">
# <center> <h1>Primera entrega </h1></center>
# </div>

# %% [markdown]
# ### Resolución

# %%
from IPython.display import IFrame
IFrame("./rsc/resolucion.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./rsc/resolucion.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# \begin{equation}
# \frac{V_2}{V_1} = - \frac{R_3}{R_1} \frac{\frac{1}{R_3²C²}}{s^2 + s \frac{1}{R_2C} + \frac{1}{R_3²C²}}
# \end{equation}
#
# \begin{equation}
# \frac{V_2}{V_1} = - K \frac{\omega_0²}{s^2 + s \frac{\omega_0}{Q} + \omega_0²}
# \end{equation}
#
# \begin{equation}
# \omega_0 = \frac{1}{R_3C} \space\space Q=\frac{R_2}{R_3} \space\space K=\frac{R_3}{R_1}
# \end{equation}
#
# Adoptando:
# \begin{equation}
# R_3 = 10k\Omega \space\space R_2 = 30k\Omega \space\space R_1=1k\Omega \space\space C= 100uF
# \end{equation}
#
# \begin{equation}
# \omega_0 = 1 \space\space Q=3 \space\space
# \end{equation}
#
# \begin{equation}
# ganancia \space de \space 20dB\space \rightarrow \space K = 10
# \end{equation}

# %% [markdown]
# ### Tipo de filtro
#
# \begin{equation}
# s\rightarrow 0 => \frac{V_2}{V_1} = -K
# \end{equation}
#
# \begin{equation}
# s\rightarrow \infty => \frac{V_2}{V_1} = 0
# \end{equation}
# El filtro es de tipo pasa bajos!

# %% [markdown]
# ### Normalización
#
# \begin{equation}
# \Omega_\omega = \omega_0 =  \frac{1}{R_3C}
# \end{equation}
#
#
# \begin{equation}
# \vec{s} = \frac{s}{\frac{1}{R_3C_1}} \rightarrow s= \frac{\vec{s}}{R_3C}
# \end{equation}
#
# \begin{equation}
# \frac{V_2}{V_1} = - \frac{R_3}{R_1} \frac{\frac{1}{R_3²C²}}{s^2 + s \frac{1}{R_2C} + \frac{1}{R_3²C²}}
# \end{equation}
#
# \begin{equation}
# \frac{V_2}{V_1} = - \frac{R_3}{R_1} \frac{1}{s^2 + \frac{R_3}{R_2}s + 1}
# \end{equation}

# %% [markdown]
# ### Verificación con SymPy

# %%
import sympy as sp
from sympy.abc import s
from IPython.display import display, Math

# %%
Vi, Vo, Vx, Vy = sp.symbols("Vi, Vo, Vx, Vy")
Y1, Y2, Y3, Y4, YC, R1, R2, R3, R4, C = sp.symbols("Y1, Y2, Y3, Y4, YC, R1, R2, R3, R4, C")

sistema = sp.solve([ 
                Vi*Y1+Vx*Y2+Vo*Y3,
                Vx-Vo*YC/Y3
            ], 
            [Vi, Vo])

transf_func = sistema[Vo]/sistema[Vi]

tlp = transf_func.subs(Y1,1/R1)
tlp = tlp.subs(Y2,1/R2+ s*C)
tlp = tlp.subs(Y3,1/R3)
tlp = tlp.subs(Y4,1/R4)
tlp = tlp.subs(YC,s*C)

num, den = sp.fraction(sp.simplify(sp.expand(tlp)))
num = sp.Poly(num,s)
den = sp.Poly(den,s)

k = num.LC() / den.LC()

num = num.monic()
den = den.monic()

den_coeffs = den.all_coeffs()
wo = den_coeffs[-1]

tlp_final = sp.Mul(k,num/den, evaluate=False)

tlp_final
# Out:
# (-1/(C**2*R1*R3))/(s**2 + s/(C*R2) + 1/(C**2*R3**2))

# %%
tlp_final.limit(s,oo)
# Out:
# 0

# %%
tlp_final.limit(s,0)
# Out:
# -R₃
# ────
#  R₁

# %%
sqrt(wo)
# Out:
#      ________
#     ╱   1
#    ╱  ──────
#   ╱    2   2
# ╲╱    C ⋅R₃

# %% [markdown]
# ### Cálculo de sensibilidades

# %%
from IPython.display import IFrame
IFrame("./rsc/sensibilidad.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./rsc/sensibilidad.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Transferencia de Butterworth

# %% [markdown]
# \begin{equation}
# \frac{V_2}{V_1} = - \frac{R_3}{R_1} \frac{1}{s^2 + \frac{R_3}{R_2}s + 1}
# \end{equation}
#
# Extracto tabla 6.2 Schaumann
# <img src="./rsc/tabla_Butterworth.png"  />
#
# \begin{equation}
# \frac{R_3}{R_2} = \sqrt 2 \rightarrow R_3 = R_2 \sqrt 2
# \end{equation}
#
# \begin{equation}
# K = 10 \rightarrow \frac{R_3}{R_1} = 10 \rightarrow R_3 = 10 R_1 \rightarrow  R_1 = \frac{R_2 \sqrt 2}{10}
# \end{equation}
#
# \begin{equation}
# C = \frac{1}{R_3} = \frac{1}{R_2 \sqrt 2}
# \end{equation}
#
# \begin{equation}
# R_2 = 10 k\Omega \\ R_3 = 10 \sqrt 2 = 14,142146k\Omega \\ R_1 = \sqrt 2= 1,4142146 k\Omega \\ C = \frac{1}{10 \sqrt 2} = 70,711 uF
# \end{equation}

# %% [markdown]
# ### Obtención de circuito pasa-banda a partir de circuito original

# %% [markdown]
# Parámetros de diseño del filtro
# \begin{equation}
# \omega_0 = \frac{1}{R_3C} \space\space Q=\frac{R_2}{R_3} \space\space K=\frac{R_3}{R_1}
# \end{equation}
#
# Forzando
# \begin{equation}
# R_1 = R_2
# \end{equation}
#
# Adoptando:
# \begin{equation}
# R_3 = 300\Omega \space\space R_1 = R_2 = 5k\Omega\space\space C= 0.01uF
# \end{equation}
#
# Parámetros de diseño pasa-banda:
# \begin{equation}
# \omega_0 = 333.333 \space\space Q=1,67 \space\space K= -24,43 dB
# \end{equation}
#
# Debido a los valores adoptados y a la igualdad forzada:
# - Disminuyó la ganancia en la banda de paso del filtro pasa-bajos.
# - Aumentó el Q provocando un aumento en el sobre impulso en w0.
# - La respuesta de fase no se modifica.

# %% [markdown]
# ### Simulación de función transferencia  con matplotlib

# %%
plotearFtrans(w0=1, Q=3,K=-10,tipo="lp",wn=0)
# Out:
# /home/facu/.local/lib/python3.10/site-packages/scipy/signal/_filter_design.py:1746: BadCoefficients: Badly conditioned filter coefficients (numerator): the results may be meaningless
#   warnings.warn("Badly conditioned filter coefficients (numerator): the "

# %% [markdown]
# ### Simulación del circuito consigna en  LTspice

# %% [markdown]
# #### Circuito:
# <img src="./rsc/sim/simConsigna/circuito.png"  />

# %% [markdown]
# #### Respuesta de modulo y fase
# <img src="./rsc/sim/simConsigna/respuesta_fase.png" align="right" width="400" />
# <img src="./rsc/sim/simConsigna/respuesta_modulo.png" align="left" width="400"  />

# %% [markdown]
# #### Parámetros caracteristicos del filtro:
# <img src="./rsc/sim/simConsigna/cursor.png" align="center" width="400"  />
#
# Frecuencia de corte del filtro:
# \begin{equation}
# f_0 = \frac{\omega_0}{2\pi} = 159 mHz \space\space f_{0sim} = 158,48 mHz
# \end{equation}
#
# El valor de Q coincide aproximadamente con el sobre pico:
# \begin{equation}
# Q_{veces} = 3  \rightarrow Q_{dB} = 20log3 = 9,54 \space\space Q_{sim} = 9,49
# \end{equation}
#
# En la frecuencia de corte la rotación de fase es de 90°

# %% [markdown]
# ### Simulación del circuito Butterworth en  LTspice

# %% [markdown]
# #### Circuito:
# <img src="./rsc/sim/simButterworth/circuito.png"  />

# %% [markdown]
# #### Respuesta de modulo y fase
# <img src="./rsc/sim/simButterworth/fase.png" align="right" width="400" />
# <img src="./rsc/sim/simButterworth/modulo.png" align="left" width="400"  />

# %% [markdown]
# - La respuesta de modulo se aplana en la banda de paso a causa de la reducción del sobreimpulso causado por el factor de calidad Q.
# - La respuesta de fase no se modifica.

# %% [markdown]
# ### Simulación del circuito pasa-banda en  LTspice

# %% [markdown]
# #### Circuito:
# <img src="./rsc/sim/simPasa-banda/circuito.png"  />

# %% [markdown]
# #### Respuesta de modulo y fase
# <img src="./rsc/sim/simPasa-banda/fase.png" align="right" width="1200" height="600" />
# <img src="./rsc/sim/simPasa-banda/modulo.png" align="left"  width="1200" height="600"   />

# %% [markdown]
# En las capturas de LtSpice se pueden verificar lo calculado anteriormente:
# \begin{equation}
# \omega_0 = 333.333 \rightarrow f_0 = \frac{333.333}{2\pi} = 53 kHz \rightarrow f_{0sim} = 52,661kHz \\ \space\space K= -24,43 dB \rightarrow K_{sim} = -24 dB
# \end{equation}
#
# La respuesta de fase no se modifica, coincidiendo la rotación de 90° con la frecuencia central del filtro.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------
# ### Funciones auxiliares

# %%
#Función para graficar Modulo, Fase, Diagrama de polos y ceros y Retardo de grupo de una función transferencia de segundo orden.
#Recibe los parámetros:
    #w0: Frecuencia de corte del filtro.
    #Q: Factor de calidad del filtro.
    #K: Ganancia en VECES CON SIGNO DE FASE
    #tipo: String para el tipo de filtro ("lp","hp","bp","ap","n")
    #wn: Frecuencia suprimida (solo para filtro Notch)

def plotearFtrans(w0,Q,K,tipo, wn):
    from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot
    from scipy.signal import TransferFunction
    import numpy as np
    import matplotlib.pyplot as plt
    import matplotlib as mpl
    
    plt.figure(1)
    plt.close(1)

    fig_sz_x = 13
    fig_sz_y = 7
    fig_dpi = 80 # dpi
    fig_font_size = 16

    mpl.rcParams['figure.figsize'] = (fig_sz_x, fig_sz_y)
    mpl.rcParams['figure.dpi'] = fig_dpi
    plt.rcParams.update({'font.size':fig_font_size})
    
    p0 = 0 
    p1 = 0
    p2 = 0
    if(tipo == "lp"):
        p0 = K*w0*w0
    elif(tipo == "bp"):
        p1 = K*w0/Q
    elif(tipo == "hp"):
        p2 = K
    elif(tipo == "n"):
        p2 = K
        p0 = K*wn*wn
    elif(tipo == "ap"):
        p0 = K*w0*w0
        p1 = -K*w0/Q
        p2 = K
    
    my_tf = TransferFunction( [p2,p1,p0], [1,w0/Q,w0*w0] )

    bodePlot(my_tf, fig_id=1, filter_description = 'w0={:3.3f}'.format(w0) )

    pzmap(my_tf, fig_id=2, filter_description = 'w0={:3.3f}'.format(w0)) #S plane pole/zero plot

    GroupDelay(my_tf, fig_id=3, filter_description = 'w0={:3.3f}'.format(w0))

# %% [markdown]
# ---------------------------------------------------------------------------------------------------
